# %%
from Tengai import dataset,preprocessing,model,visual_series
from Tengai_demo.playground import TimeSeries_Demo,DemoCluster,city_long_lat

# %%
lat,long = city_long_lat("jakarta")
data = dataset.AirQuality(lat,long)
demo_time_series = TimeSeries_Demo(data,"pm10")
demo_time_series.visual_time_series()
